# %%
import pandas as pd

# %%
import jsonlines
import pandas as pd

# Open the JSONL file in read mode
with jsonlines.open('/data/shared/incas/Israel_Hamas/data/challenge_problem_two_21NOV.jsonl') as reader:
    # Initialize an empty list to store the JSON objects
    data = []
    
    # Iterate over each line in the file
    for line in reader:
        # Process each line as a JSON object
        data.append(line)
    
    # Create a pandas DataFrame from the list of JSON objects
    df = pd.DataFrame(data)

# %%
print(len(df[df['author'].notnull()]))
print(len(df['author']))
df.head()
# Out:
# 104704
# 3688879
#   annotations dataTags                                       embeddedUrls  \
# 0          []       []                                                 []
# 1          []       []  [https://alkoofiya.net/2023/08/31/israeli-forc...
# 2          []       []  [https://www.newarab.com/news/libyas-prime-min...
# 3          []       []                                                 []
# 4          []       []                                                 []
#
#   extraAttributes                                          imageUrls segments  \
# 0              []                                                 []       []
# 1              []                                                 []       []
# 2              []                                                 []       []
# 3              []  [https://video.twimg.com/ext_tw_video/16973106...       []
# 4              []   [http://pbs.twimg.com/media/F43Jq-DWsAAeMut.jpg]       []
#
#   author                                        contentText geolocation  \
# 0   waiv  The fact that they covered up Saudi Arab murde...        None
# 1   None  RT @Palnews22 Israeli forces detain 17 Palesti...        None
# 2   None  Libya's prime minister rejects normalization w...        None
# 3   None  RT @tomas_4040 فلسطيني يجلد الفلسطينيين ..👨‍🦰👨...        None
# 4   None  RT @QudsNen A new report commissioned by the U...        None
#
#                                          id language mediaType  \
# 0  254b51c270d10b3de6b2863ec6a3568462e2af8a  English    Reddit
# 1  b40146ee736fa722f06134005d1376d307b9cc66  English   Twitter
# 2  1390241ea783b3ff66694dc1977ac4cc0a8ddf4e  English   Twitter
# 3  5f8644b3566122f533d7337bf820ef1cc2b1da89   Arabic   Twitter
# 4  5a0cc00070f584b4def30951ca28b2cceaf8d1ee  English   Twitter
#
#                                  mediaTypeAttributes  \
# 0  {'redditData': {'author': 'waiv', 'authorAward...
# 1  {'twitterData': {'mentionedUsers': ['ace493f1e...
# 2  {'twitterData': {'mentionedUsers': [], 'engage...
# 3  {'twitterData': {'mentionedUsers': ['f2f9c9ca7...
# 4  {'twitterData': {'mentionedUsers': [], 'engage...
#
#                                                 name  timePublished  \
# 0  messages/254b51c270d10b3de6b2863ec6a3568462e2af8a  1693529993000
# 1  messages/b40146ee736fa722f06134005d1376d307b9cc66  1693529940000
# 2  messages/1390241ea783b3ff66694dc1977ac4cc0a8ddf4e  1693529912000
# 3  messages/5f8644b3566122f533d7337bf820ef1cc2b1da89  1693529566000
# 4  messages/5a0cc00070f584b4def30951ca28b2cceaf8d1ee  1693529444000
#
#                                                title translatedContentText  \
# 0  ‘It’s like 1948’: Israel cleanses vast West Ba...                  None
# 1  RT @Palnews22 Israeli forces detain 17 Palesti...                  None
# 2  Libya's prime minister rejects normalization w...                  None
# 3  RT @tomas_4040 فلسطيني يجلد الفلسطينيين ..👨‍🦰👨...                  None
# 4  RT @QudsNen A new report commissioned by the U...                  None
#
#   translatedTitle                                                url
# 0            None  https://www.reddit.com/r/anime_titties/comment...
# 1            None  http://twitter.com/MangyMedia/statuses/1697413...
# 2            None  http://twitter.com/Eye_On_Gaza/statuses/169741...
# 3            None  http://twitter.com/fog213/statuses/16974121472...
# 4            None  http://twitter.com/MalcolmX81/statuses/1697411...

# %%
df = pd.read_pickle("df_author_timeseries.pkl")
df["timePublished"]
# Out:
# 3417     [1693568037000, 1693599425000, 1693611756000, ...
# 58357    [1694213100000, 1696493055000, 1696592596000, ...
# 36170    [1696678613000, 1696693769000, 1696700155000, ...
# 58361    [1696652150000, 1696660183000, 1696660035000, ...
# 30445    [1696680783000, 1696693619000, 1696698407000, ...
#                                ...
# 22921                                      [1697514871000]
# 22922                                      [1697982920000]
# 22923                                      [1696996701000]
# 22924                                      [1696197902000]
# 29199                                      [1697285055000]
# Name: timePublished, Length: 58398, dtype: object

# %%
def cleanTimeHelper(lst):
    for i in range(len(lst)):
        lst[i] -= lst[i] % (24 * 60 * 60)

        dic = {}
        for i in lst:
            if i in dic:
                dic[i] += 1
            else:
                dic[i] = 1
        
        date = []
        count = []

        seq = sorted(dic.keys())
        for key in seq:
            date.append(key)
            count.append(dic[key])

        return [date, count]

                
df['dayPublished'] = df['timePublished'].apply(cleanTimeHelper)

# %%
type(df[df['author'] == "AutoModerator"]["dayPublished"].iloc[0][0])
# Out:
# list

# %%
df_author_timeseries = df_author.groupby('author')['timePublished'].agg(list).reset_index()
df_author_timeseries['list_length'] = df_author_timeseries['timePublished'].apply(len)

# Sort the DataFrame by the 'list_length' column in descending order
df_author_timeseries = df_author_timeseries.sort_values(by='list_length', ascending=False)

# If you want to remove the 'list_length' column after sorting, you can drop it
df_author_timeseries = df_author_timeseries.drop('list_length', axis=1)
# Out:
#           author    timePublished
# 0       ---77---  [1696947181000]
# 1           ---E  [1698745433000]
# 2  ---Loading---  [1697288360000]
# 3     ---x__x---  [1697642047000]
# 4         --A3--  [1696710400000]

# %%
df_author_timeseries.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/youlyu2/model_explore/read_raw_data.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bincas.csl.illinois.edu/home/youlyu2/model_explore/read_raw_data.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df_author_timeseries.head(5)
#
# NameError: name 'df_author_timeseries' is not defined

# %%
df_author_timeseries.to_pickle("df_author_timeseries.pkl")

# %%
df_author_timeseries[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/you_venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/youlyu2/model_explore/read_raw_data.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bincas.csl.illinois.edu/home/youlyu2/model_explore/read_raw_data.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df_author_timeseries[0]
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
df_author_timeseries[df_author_timeseries["author"] == "waiv"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/you_venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'author'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/youlyu2/model_explore/read_raw_data.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bincas.csl.illinois.edu/home/youlyu2/model_explore/read_raw_data.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df_author_timeseries[df_author_timeseries["author"] == "waiv"]
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/you_venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'author'

# %%
df.head()
# Out:
#   annotations dataTags                                       embeddedUrls  \
# 0          []       []                                                 []
# 1          []       []  [https://alkoofiya.net/2023/08/31/israeli-forc...
# 2          []       []  [https://www.newarab.com/news/libyas-prime-min...
# 3          []       []                                                 []
# 4          []       []                                                 []
#
#   extraAttributes                                          imageUrls segments  \
# 0              []                                                 []       []
# 1              []                                                 []       []
# 2              []                                                 []       []
# 3              []  [https://video.twimg.com/ext_tw_video/16973106...       []
# 4              []   [http://pbs.twimg.com/media/F43Jq-DWsAAeMut.jpg]       []
#
#   author                                        contentText geolocation  \
# 0   waiv  The fact that they covered up Saudi Arab murde...        None
# 1   None  RT @Palnews22 Israeli forces detain 17 Palesti...        None
# 2   None  Libya's prime minister rejects normalization w...        None
# 3   None  RT @tomas_4040 فلسطيني يجلد الفلسطينيين ..👨‍🦰👨...        None
# 4   None  RT @QudsNen A new report commissioned by the U...        None
#
#                                          id language mediaType  \
# 0  254b51c270d10b3de6b2863ec6a3568462e2af8a  English    Reddit
# 1  b40146ee736fa722f06134005d1376d307b9cc66  English   Twitter
# 2  1390241ea783b3ff66694dc1977ac4cc0a8ddf4e  English   Twitter
# 3  5f8644b3566122f533d7337bf820ef1cc2b1da89   Arabic   Twitter
# 4  5a0cc00070f584b4def30951ca28b2cceaf8d1ee  English   Twitter
#
#                                  mediaTypeAttributes  \
# 0  {'redditData': {'author': 'waiv', 'authorAward...
# 1  {'twitterData': {'mentionedUsers': ['ace493f1e...
# 2  {'twitterData': {'mentionedUsers': [], 'engage...
# 3  {'twitterData': {'mentionedUsers': ['f2f9c9ca7...
# 4  {'twitterData': {'mentionedUsers': [], 'engage...
#
#                                                 name  timePublished  \
# 0  messages/254b51c270d10b3de6b2863ec6a3568462e2af8a  1693529993000
# 1  messages/b40146ee736fa722f06134005d1376d307b9cc66  1693529940000
# 2  messages/1390241ea783b3ff66694dc1977ac4cc0a8ddf4e  1693529912000
# 3  messages/5f8644b3566122f533d7337bf820ef1cc2b1da89  1693529566000
# 4  messages/5a0cc00070f584b4def30951ca28b2cceaf8d1ee  1693529444000
#
#                                                title translatedContentText  \
# 0  ‘It’s like 1948’: Israel cleanses vast West Ba...                  None
# 1  RT @Palnews22 Israeli forces detain 17 Palesti...                  None
# 2  Libya's prime minister rejects normalization w...                  None
# 3  RT @tomas_4040 فلسطيني يجلد الفلسطينيين ..👨‍🦰👨...                  None
# 4  RT @QudsNen A new report commissioned by the U...                  None
#
#   translatedTitle                                                url
# 0            None  https://www.reddit.com/r/anime_titties/comment...
# 1            None  http://twitter.com/MangyMedia/statuses/1697413...
# 2            None  http://twitter.com/Eye_On_Gaza/statuses/169741...
# 3            None  http://twitter.com/fog213/statuses/16974121472...
# 4            None  http://twitter.com/MalcolmX81/statuses/1697411...
